# %% [markdown]
# # 🚉 IndicRail-Translate: Domain-Specific NMT System
# **Major Project | Gati Shakti Vishwavidyalaya**
#
# **Objective:** Neural Machine Translation for Technical Railway & Logistics Documentation (English to Hindi/Marathi).
# **Model:** Meta's M2M-100 (Many-to-Many Transformer)

# %%
# 1. Installing Libraries
# !pip install transformers sentencepiece accelerate nltk -q

# 2. Downloading NLTK Resources (Fixing the punkt_tab error)
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')

import torch
from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer
from nltk.tokenize import sent_tokenize

print("✅ Setup Complete: All libraries and resources loaded.")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# ✅ Setup Complete: All libraries and resources loaded.

# %%
class IndicRailTranslator:
    def __init__(self):
        self.model_name = "facebook/m2m100_418M"
        self.device = "cuda" if torch.cuda.is_available() else "cpu"

        print(f"🚀 Loading model on {self.device}...")
        self.tokenizer = M2M100Tokenizer.from_pretrained(self.model_name)
        self.model = M2M100ForConditionalGeneration.from_pretrained(self.model_name).to(self.device)
        print("✅ Neural Engine Loaded Successfully")

    def translate_process(self, text, target_lang):
        if not text.strip(): return "Error: Input is empty."

        lang_code = "hi" if target_lang == "Hindi" else "mr"
        sentences = sent_tokenize(text)
        results = []

        for sent in sentences:
            self.tokenizer.src_lang = "en"
            inputs = self.tokenizer(sent, return_tensors="pt").to(self.device)
            output_tokens = self.model.generate(
                **inputs,
                forced_bos_token_id=self.tokenizer.get_lang_id(lang_code),
                num_beams=5,
                early_stopping=True
            )
            decoded = self.tokenizer.batch_decode(output_tokens, skip_special_tokens=True)[0]
            results.append(decoded)
        return " ".join(results)

# Initialize
engine = IndicRailTranslator()
# Out:
# 🚀 Loading model on cuda...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ✅ Neural Engine Loaded Successfully

# %%
# @title 🚉 INDICRAIL-TRANSLATE v1.0 { display-mode: "form" }
# @markdown Enter your technical text below and click the 'Play' button.

English_Text = "Railway signaling systems must be checked every month for passenger safety." # @param {type:"string"}
Target_Language = "Hindi" # @param ["Hindi", "Marathi"]

if English_Text:
    print("⏳ Processing Technical Translation...")
    # Fix: Matching the function name with the class above
    output = engine.translate_process(English_Text, Target_Language)

    print("\n" + "="*70)
    print(f"📂 SOURCE (EN): {English_Text}")
    print("-" * 70)
    print(f"🎯 TRANSLATED ({Target_Language}): {output}")
    print("="*70)
# Out:
# ⏳ Processing Technical Translation...
#
# ======================================================================
# 📂 SOURCE (EN): Railway signaling systems must be checked every month for passenger safety.
# ----------------------------------------------------------------------
# 🎯 TRANSLATED (Hindi): यात्रियों की सुरक्षा के लिए रेलवे सिग्नल सिस्टम को हर महीने जांच की जानी चाहिए।
# ======================================================================

# %%
# Test the brain first
test_text = "The railway station is under renovation."
try:
    hindi_res = engine.translate_process(test_text, "Hindi")
    print(f"✅ Engine is Working!\nInput: {test_text}\nOutput: {hindi_res}")
except Exception as e:
    print(f"❌ Engine Error: {e}")
# Out:
# ✅ Engine is Working!
# Input: The railway station is under renovation.
# Output: रेलवे स्टेशन की मरम्मत की जा रही है।

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# @title 🚉 IndicRail-Translate Dashboard
# @markdown Paste your English text and select the language. Then click the play button.

English_Text = "The Indian Railways is modernizing its infrastructure with high-speed corridors." # @param {type:"string"}
Target_Language = "Hindi" # @param ["Hindi", "Marathi"]

# 1. Download required NLTK resources
import nltk
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)

# 2. Run Translation
try:
    print("🚀 Translating... Please wait.")
    output = engine.translate_process(English_Text, Target_Language)

    print("\n" + "="*50)
    print(f"SOURCE (English): {English_Text}")
    print(f"TRANSLATED ({Target_Language}): {output}")
    print("="*50)
except Exception as e:
    print(f"❌ Error: {e}")
# Out:
# 🚀 Translating... Please wait.
#
# ==================================================
# SOURCE (English): The Indian Railways is modernizing its infrastructure with high-speed corridors.
# TRANSLATED (Hindi): भारतीय रेलवे अपनी बुनियादी ढांचे को उच्च गति वाले गलियारे के साथ आधुनिकीकरण कर रहा है।
# ==================================================

# %%
# !pip uninstall gradio -y
# !pip install gradio==3.50.2 --no-cache-dir
# Out:
# Found existing installation: gradio 4.44.1
# Uninstalling gradio-4.44.1:
#   Successfully uninstalled gradio-4.44.1
# Collecting gradio==3.50.2
#   Downloading gradio-3.50.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (5.5.0)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (0.123.10)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (1.0.0)
# Collecting gradio-client==0.6.1 (from gradio==3.50.2)
#   Downloading gradio_client-0.6.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (0.36.0)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (6.5.2)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (3.1.6)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (3.10.0)
# Requirement already satisfied: numpy~=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (3.11.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (2.2.2)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (10.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (2.10.5)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (0.25.1)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (0.0.21)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (6.0.3)
# Requirement already satisfied: requests~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (2.32.4)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (2.10.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (0.40.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /usr/local/lib/python3.12/dist-packages (from gradio==3.50.2) (11.0.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==0.6.1->gradio==3.50.2) (2025.3.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair<6.0,>=4.2.0->gradio==3.50.2) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair<6.0,>=4.2.0->gradio==3.50.2) (2.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.14.0->gradio==3.50.2) (3.20.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.14.0->gradio==3.50.2) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.14.0->gradio==3.50.2) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==3.50.2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==3.50.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==3.50.2) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==3.50.2) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==3.50.2) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==3.50.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==3.50.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==3.50.2) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4->gradio==3.50.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4->gradio==3.50.2) (2.27.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests~=2.0->gradio==3.50.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests~=2.0->gradio==3.50.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests~=2.0->gradio==3.50.2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests~=2.0->gradio==3.50.2) (2026.1.4)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.14.0->gradio==3.50.2) (8.3.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.14.0->gradio==3.50.2) (0.16.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi->gradio==3.50.2) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi->gradio==3.50.2) (0.0.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx->gradio==3.50.2) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->gradio==3.50.2) (1.0.9)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.50.2) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.50.2) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.50.2) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.50.2) (0.30.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==3.50.2) (1.17.0)
# Downloading gradio-3.50.2-py3-none-any.whl (20.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 86.2 MB/s eta 0:00:00
# Downloading gradio_client-0.6.1-py3-none-any.whl (299 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 216.2 MB/s eta 0:00:00
# Installing collected packages: gradio-client, gradio
#   Attempting uninstall: gradio-client
#     Found existing installation: gradio_client 1.3.0
#     Uninstalling gradio_client-1.3.0:
#       Successfully uninstalled gradio_client-1.3.0
# Successfully installed gradio-3.50.2 gradio-client-0.6.1

# %%
import gradio as gr

# 1. Wrapper function jo UI aur Engine ko joddta hai
def translate_wrapper(text, language):
    if not text.strip():
        return "Bhai, kuch text toh daalo!"
    # 'engine' humne upar class mein initialize kiya tha
    return engine.translate_process(text, language)

# 2. Interface Design (Tera Fav Purana Style + Themes)
with gr.Blocks(theme=gr.themes.Soft()) as demo:
    gr.Markdown("# 🚉 IndicTranslate AI: GSV Major Project")
    gr.Markdown("Technical Railway Documents ko English se Hindi/Marathi mein translate karein.")

    with gr.Row():
        with gr.Column():
            input_box = gr.Textbox(
                label="English Article",
                placeholder="Technical text yahan paste karein...",
                lines=10
            )
            lang_choice = gr.Radio(["Hindi", "Marathi"], label="Bhasha Chunein", value="Hindi")
            btn = gr.Button("Translate ✨", variant="primary")

        with gr.Column():
            output_box = gr.Textbox(label="Translated Output", lines=12, interactive=False)

    # Logic Connection
    btn.click(fn=translate_wrapper, inputs=[input_box, lang_choice], outputs=output_box)

# 3. Launch with Public Link
# 'share=True' se tujhe ek public link milega jo tu sabko bhej sakta hai
demo.launch(share=True, debug=True)
# Out:
# IMPORTANT: You are using gradio version 3.50.2, however version 4.44.1 is available, please upgrade.
# --------
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://21404fa7245338eaa4.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://21404fa7245338eaa4.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
